# %%
'''
Besnik Balaj
A01 for Intro to NLP
I pledge my honor that I have abided by the Stevens Honor System - Besnik Balaj
'''

# %%
'''
Respond to the first seven Your Turn practices from BKL Chapter 1 
on pages 5, 8, 11, 14, and 19 in the paperback edition. 
Show screen shots or submit an Anaconda jupyter Notebook as an .ipynb file. 
There is another on p32 that might be fun but is not required.
'''
# Out:
# '\nRespond to the first seven Your Turn practices from BKL Chapter 1 \non pages 5, 8, 11, 14, and 19 in the paperback edition. \nShow screen shots or submit an Anaconda jupyter Notebook as an .ipynb file. \nThere is another on p32 that might be fun but is not required.\n'

# %%
'''
Your Turn 1
Page 2:
 Enter a few more expressions of your own. You can use asterisk (*) for multiplication and slash (/) for division, 
 and parentheses for bracketing expressions. Note that division doesn’t always behave as you might expect—it does 
 integer division (with rounding of fractions downwards) when you type 1/3 and “floating-point” (or decimal) 
 divi- sion when you type 1.0/3.0. In order to get the expected behavior of division (standard in Python 3.0), 
 you need to type: from __future__ import division.
'''
#Did not think this counted but will do it anyway
print(5*10)
print(5/10)
print(5.0/10.0)
print(5**2)
print(56//5)#checking this out
# Out:
# 50
# 0.5
# 0.5
# 25
# 11

# %%
import random as r 
import numpy
import matplotlib

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
'''
Your Turn 2
PAGE 5: Your Turn

 Try searching for other words; to save re-typing, you might be able to use up-arrow, Ctrl-up-arrow, or 
 Alt-p to access the previous command and modify the word being searched. You can also try search- es on some of 
 the other texts we have included. For example, search Sense and Sensibility for the word affection, 
 using text2.concord ance("affection"). Search the book of Genesis to find out how long some people lived, 
 using: text3.concordance("lived"). You could look at text4, the Inaugural Address Corpus, to see examples of English 
 going back to 1789, and search for words like nation, terror, god to see how these words have been used differently 
 over time. We’ve also included text5, the NPS Chat Corpus: search this for unconventional words like im, ur, lol. 
 (Note that this corpus is uncensored!)
 
I'm going to use for loops

'''

# %%
words = ["monstrous","Dick","terror","posterior","Grail","affection","lived","God"]
text = [text1,text2,text3,text4,text5,text6,text7,text8,text9] #I feel there may be a better way to call this

# %%
for i in text:
    print("###############THIS IS A BREAK##############")
    print(i)#print which text I am looking at
    for j in words:
        print(j)
        i.concordance(j)
# Out:
# ###############THIS IS A BREAK##############
# <Text: Moby Dick by Herman Melville 1851>
# monstrous
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# ...

# %%
'''
Your Turn 3
Page 6
Pick another pair of words 
and compare their usage in two different texts, 
using the similar() and common_contexts() functions
'''
# Out:
# '\nPick another pair of words \nand compare their usage in two different texts, \nusing the similar() and common_contexts() functions\n'

# %%
words = [["monstrous","Dick"],["terror","posterior"],["Grail","affection"],["lived","God"]]

# %%
for i in text:
    print(f"BREAK:,Beginning to work on {i}. We will compare their usage in the texts using similar and common_contexts.")
    for l in words:
        print(f"BREAK: Similar Test with word {l[0]}")
        i.similar(l[0])
        print(f"BREAK: Similar Test with word {l[1]}")
        i.similar(l[0])
        print(f"BREAK: Common_Contexts Test with word {l}")
        i.common_contexts(l)
# Out:
# BREAK:,Beginning to work on <Text: Moby Dick by Herman Melville 1851>. We will compare their usage in the texts using similar and common_contexts.
# BREAK: Similar Test with word monstrous
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
# BREAK: Similar Test with word Dick
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
# BREAK: Common_Contexts Test with word ['monstrous', 'Dick']
# No common contexts were found
# BREAK: Similar Test with word terror
# man whale thing land way ship voyage bone night distance harpooneer
# sight picture sign sound speed school him it them
# BREAK: Similar Test with word posterior
# man whale thing land way ship voyage bone night distance harpooneer
# sight picture sign sound speed school him it them
# ...

# %%
#print(f"BREAK: Does this work {words[0]}")

# %%
'''
Your Turn 4
Page 8
How many times does the word 
lol appear in text5? How much is this as a 
percentage of the total number of words in this text?
'''
#Just need to follow their previous example, I can't do much fun here. I am guessing 0
amt = text5.count('lol')
percent = 100 * (text4.count('a') / len(text4))
print(f"The amount of times lol appeared in text 5 is {amt} while the percentage of it is {percent}")
# Out:
# The amount of times lol appeared in text 5 is 704 while the percentage of it is 1.457973123627309

# %%
#Note, I am highly amazed lol appeared there
#text5.concordance('lol')
#Ah, it is a Chat Corpus where I thought it was the Holy Grail
# Out:
# Displaying 25 of 822 matches:
# ast PART 24 / m boo . 26 / m and sexy lol U115 boo . JOIN PART he drew a girl w
# ope he didnt draw a penis PART ewwwww lol & a head between her legs JOIN JOIN s
# a bowl i got a blunt an a bong ...... lol JOIN well , glad it worked out my cha
# e " PART Hi U121 in ny . ACTION would lol @ U121 . . . but appearently she does
# 30 make sure u buy a nice ring for U6 lol U7 Hi U115 . ACTION isnt falling for
#  didnt ya hear !!!! PART JOIN geeshhh lol U6 PART hes deaf ppl here dont get it
# es nobody here i wanna misbeahve with lol JOIN so read it . thanks U7 .. Im hap
# ies want to chat can i talk to him !! lol U121 !!! forwards too lol JOIN ALL PE
# k to him !! lol U121 !!! forwards too lol JOIN ALL PErvs ... redirect to U121 '
#  loves ME the most i love myself JOIN lol U44 how do u know that what ? jerkett
# ng wrong ... i can see it in his eyes lol U20 = fiance Jerketts lmao wtf yah I
# ...

# %%
'''
Your Turn 5
Page 11
Make up a few sentences of your own, by typing a name, equals sign, and a list of words, 
like this: ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']. Repeat some of the other 
Python op- erations we saw earlier in Section 1.1, e.g., sorted(ex1), len(set(ex1)), ex1.count('the').
'''
ex1=['Besnik','is','taking','NLP']
ex2=['Besnik','is','trying', 'to','play','WoW', 'Classic']
ex3=['This','is','the','last','sentence']
ex4=['I','\'','m']
Exs = [ex1,ex2,ex3,ex4]
words = ['Besnik','is','WoW','Crazy']
for i in Exs:
    print('First let us sort the example sentences')
    print(sorted(i))
    print('Second let us get the length')
    print(len(set(i)))
    print('Thirdly now lets count some words that may be present in the list')
    for l in words:
        print(f"The amount of times {l} appears in this sentence is: {i.count(l)}")
# Out:
# First let us sort the example sentences
# ['Besnik', 'NLP', 'is', 'taking']
# Second let us get the length
# 4
# Thirdly now lets count some words that may be present in the list
# The amount of times Besnik appears in this sentence is: 1
# The amount of times is appears in this sentence is: 1
# The amount of times WoW appears in this sentence is: 0
# The amount of times Crazy appears in this sentence is: 0
# First let us sort the example sentences
# ['Besnik', 'Classic', 'WoW', 'is', 'play', 'to', 'trying']
# Second let us get the length
# 7
# Thirdly now lets count some words that may be present in the list
# The amount of times Besnik appears in this sentence is: 1
# The amount of times is appears in this sentence is: 1
# The amount of times WoW appears in this sentence is: 1
# The amount of times Crazy appears in this sentence is: 0
# First let us sort the example sentences
# ['This', 'is', 'last', 'sentence', 'the']
# Second let us get the length
# 5
# ...

# %%
'''
Your Turn 6
Page 14
Take a few minutes to define a sentence of your own and modify individual words and 
groups of words (slices) using the same methods used earlier. 
Check your understanding by trying the exercises on lists at the end of this chapter.
'''
Exsent = ['The','Bird','and', 'the', 'Bee', 'met', 'in', 'the', 'tree', ',' ,'cool', '.']
print(Exsent)
print(Exsent[3:5])
Exsent[3:5] = "REPLACED"
print(Exsent)
print('BREAK')
#Not really sure what it reallt wants here 
for i in range(0,len(Exsent),2):
    Exsent[i] = 'REDACTED'
print('BREAK')
print(Exsent)
# Out:
# ['The', 'Bird', 'and', 'the', 'Bee', 'met', 'in', 'the', 'tree', ',', 'cool', '.']
# ['the', 'Bee']
# ['The', 'Bird', 'and', 'R', 'E', 'P', 'L', 'A', 'C', 'E', 'D', 'met', 'in', 'the', 'tree', ',', 'cool', '.']
# BREAK
# BREAK
# ['REDACTED', 'Bird', 'REDACTED', 'R', 'REDACTED', 'P', 'REDACTED', 'A', 'REDACTED', 'E', 'REDACTED', 'met', 'REDACTED', 'the', 'REDACTED', ',', 'REDACTED', '.']

# %%
'''
Your Turn 7
Page 18
Try the preceding frequency distribution example for your-self, for text2. 
Be careful to use the correct parentheses and uppercase letters. 
If you get an error message NameError: name 'FreqDist' is not defined, 
you need to start your work with from nltk.book import *.
'''
#print(text)
fdist1=FreqDist(text2)
print(fdist1)
vocabulary1 = list(fdist1.keys())
print(vocabulary1[:50])
#https://stackoverflow.com/questions/26394748/nltk-python-error-typeerror-dict-keys-object-is-not-subscriptable
##Found out this becomes an issue when using Python3 over Python2, not sure which we need to use overall
fdist1['sense']


#A little fun here now
words = ["monstrous","Dick","terror","posterior","Grail","affection","lived","God"]
text = [text1,text2,text3,text4,text5,text6,text7,text8,text9] #I feel there may be a better way to call this

for i in text:
    print("###############THIS IS A BREAK##############")
    fdist1=FreqDist(i)
    print(fdist1)
    vocabulary1 = list(fdist1.keys())
    print(vocabulary1[:50])
    for j in words:
        print(f"We are looking for frequency of this word {j}")
        print(fdist1[j])
# Out:
# <FreqDist with 6833 samples and 141576 outcomes>
# ['[', 'Sense', 'and', 'Sensibility', 'by', 'Jane', 'Austen', '1811', ']', 'CHAPTER', '1', 'The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.', 'Their', 'estate', 'was', 'large', ',', 'their', 'residence', 'at', 'Norland', 'Park', 'the', 'centre', 'property', 'where', 'for', 'many', 'generations', 'they', 'lived', 'so', 'respectable', 'a', 'manner', 'as', 'to', 'engage', 'general', 'good']
# ###############THIS IS A BREAK##############
# <FreqDist with 19317 samples and 260819 outcomes>
# ...

# %%
'''
Your Turn 8(maybe 7)
Page 19
Your Turn: Try out the previous statements in the Python interpreter, 
and experiment with changing the text and changing the length condi- tion. 
Does it make an difference to your results if you change the variable names, 
e.g., using [word for word in vocab if ...]?
'''
#First how they did it
#V = set(text1)
#long_words = [w for w in V if len(w) > 15]
#sorted(long_words)
#Test out variable name changes
Vocab = set(text1)
long_words = [word for word in Vocab if len(word) > 15]
sorted(long_words)
##Clearly if you change the variable names (wherever they appear and not just in 1 place) then the result should be the same
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
for i in text:
    print(f"We will now do the length test for {i}")
    for j in range(15,20):
        long_words = [w for w in i if len(w) > j]
    print(sorted(long_words))
# Out:
# We will now do the length test for <Text: Moby Dick by Herman Melville 1851>
# ['uninterpenetratingly']
# We will now do the length test for <Text: Sense and Sensibility by Jane Austen 1811>
# []
# We will now do the length test for <Text: The Book of Genesis>
# []
# We will now do the length test for <Text: Inaugural Address Corpus>
# []
# We will now do the length test for <Text: Chat Corpus>
# ...

# %%
for i in text:
    print(f"We will now do the length test for {i}")
    for j in range(5,15):#Use this to test various lengths
        long_words = [w for w in i if len(w) > j]
    print(sorted(long_words))
    print("#############################################")
# Out:
# We will now do the length test for <Text: Moby Dick by Herman Melville 1851>
# ...

# %%
###################################################################
